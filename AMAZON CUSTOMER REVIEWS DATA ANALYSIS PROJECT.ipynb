# %% [markdown]
# #           AMAZON CUSTOMER REVIEWS DATA ANALYSIS PROJECT
# ![image.png](attachment:image.png)

# %% [markdown]
# IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# IMPORTING THE DATASET

# %%
raw_df=pd.read_csv('Reviews.csv')
raw_df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
raw_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
raw_df.tail()
# Out:
#             Id   ProductId          UserId              ProfileName  \
# 568449  568450  B001EO7N10  A28KG5XORO54AY         Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z            pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH  Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                 srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 568449                 Will not do without
# ...

# %% [markdown]
# GETTING BASIC INFORMATION ABOUT THE DATASET

# %%
raw_df.shape
# Out:
# (568454, 10)

# %%
raw_df.size
# Out:
# 5684540

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568438 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
raw_df.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  568454.000000         568454.000000            568454.00000
# mean   284227.500000              1.743817                 2.22881
# std    164098.679298              7.636513                 8.28974
# min         1.000000              0.000000                 0.00000
# 25%    142114.250000              0.000000                 0.00000
# 50%    284227.500000              0.000000                 1.00000
# 75%    426340.750000              2.000000                 2.00000
# max    568454.000000            866.000000               923.00000
#
#                Score          Time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.310436  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09

# %% [markdown]
# CHECKING NULL RECORDS IN THE DATASET

# %%
raw_df.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
#Dropping the null values from the dataset
raw_df=raw_df.dropna()

# %%
raw_df.isnull().sum()
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# Summary                   0
# Text                      0
# dtype: int64

# %% [markdown]
# COPYING THE CLEANED DATA INTO A NEW DATAFRAME

# %%
reviews_df=raw_df.copy()

# %%
reviews_df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
reviews_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
reviews_df.tail()
# Out:
#             Id   ProductId          UserId              ProfileName  \
# 568449  568450  B001EO7N10  A28KG5XORO54AY         Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z            pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH  Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                 srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 568449                 Will not do without
# ...

# %%
reviews_df.shape
# Out:
# (568411, 10)

# %%
reviews_df.size
# Out:
# 5684110

# %% [markdown]
# CLEANING THE SUMMARY COLUMN

# %%
# CONVERTING THE SUMMARY COLUMN INTO LOWERCASE
reviews_df['Summary']=reviews_df['Summary'].str.lower()

# %%
reviews_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  good quality dog food  I have bought several of the Vitality canned d...
# ...

# %%
#IMPORTING REGEX LIBRARY
import re

# %%
#STORING A SAMPLE RECORD FROM THE SUMMARY COLUMN INTO THE TEXT
text=reviews_df['Summary'][2]
text
# Out:
# '"delight" says it all'

# %%
#REMOVING THE PUNCTUATION IN THE RECORD BY PASSING IT TO THE METHODS
'''
\w :Returns a match where the string contains any word characters 
    (characters from a to Z, digits from 0-9, and the underscore _ character)
\s :Returns a match where the string contains a white space character
'''
re.sub(r'[^\w\s]','',text)
# Out:
# 'delight says it all'

# %%
#CREATING A FOR LOOP TO REMOVE THE PUNCTUATION FROM ALL THE RECORDS AND THEN STORING THEM INTO A NEW SERIES
Summary_Cleaned=[]
for char in reviews_df['Summary']:
    Summary_Cleaned.append(re.sub(r'[^\w\s]','',char))

# %%
Summary_Cleaned
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy',
#  'nice taffy',
#  'great  just as good as the expensive brands',
#  'wonderful tasty taffy',
#  'yay barley',
#  'healthy dog food',
#  'the best hot sauce in the world',
#  'my cats love this diet food better than their regular food',
#  'my cats are not fans of the new food',
#  'fresh and greasy',
#  'strawberry twizzlers  yummy',
#  'lots of twizzlers just what you expect',
#  'poor taste',
#  'love it',
#  'great sweet candy',
#  'home delivered twizlers',
#  'always fresh',
#  'twizzlers',
#  'delicious product',
#  'twizzlers',
#  'please sell these in mexico',
#  'twizzlers  strawberry',
#  'nasty no flavor',
#  'great bargain for the price',
#  'yummy',
#  'the best hot sauce in the world',
#  'great machine',
#  'this is my taste',
#  'best of the instant oatmeals',
#  'good instant',
#  'great irish oatmeal for those in a hurry',
#  'satisfying',
# ...

# %%
# CHECKING THE LENGTH OF THE NEW SERIES
len(Summary_Cleaned)
# Out:
# 568411

# %%
#CHECKING THE FIRST 5 RECORDS OF THE NEW SERIES
Summary_Cleaned[0:5]
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy']

# %%
#STORING THE CLEANED SERIES BACK TO THE ORIGINAL SERIES
reviews_df['Summary_Cleaned']=Summary_Cleaned

# %%
reviews_df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
# ...

# %%
reviews_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  good quality dog food  I have bought several of the Vitality canned d...
# ...

# %%
reviews_df.tail()
# Out:
#             Id   ProductId          UserId              ProfileName  \
# 568449  568450  B001EO7N10  A28KG5XORO54AY         Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z            pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH  Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                 srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 568449                 will not do without
# ...

# %% [markdown]
# PERFORMING SENTIMENT ANALYSIS ON SUMMARY COLUMN

# %%
#IMPORTING TextBlob LIBRARY
from textblob import TextBlob

# %%
#STORING A SAMPLE RECORD FROM THE SUMMARY COLUMN INTO THE TEXT
text=reviews_df['Summary_Cleaned'][0]
text
# Out:
# 'good quality dog food'

# %%
#TESTING OUT THE SENTIMENT ANALYSIS ON THE TEXT
TextBlob(text).sentiment.polarity
# Out:
# 0.7

# %%
#CREATING A FOR LOOP TO FIND THE SENTIMENT OF ALL THE RECORDS AND THEN STORING IT INTO A NEW SERIES
summary_polarity=[]
for i in reviews_df['Summary_Cleaned']:
    summary_polarity.append(TextBlob(i).sentiment.polarity)

# %%
#CHECKING THE LENGTH OF THE NEWLY CREATED SERIES
len(summary_polarity)
# Out:
# 568411

# %%
#STORING THE NEW SERIES TO THE ORIGINAL DATABASE
reviews_df['Summary_Polarity']=summary_polarity

# %%
reviews_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  good quality dog food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# PERFORMING EDA FOR POSITIVE REVIEWS

# %%
#CREATING A NEW SERIES FOR ALL THE POSITIVE REVIEW RECORDS
positive_reviews_df=reviews_df[reviews_df['Summary_Polarity']>0]

# %%
positive_reviews_df.shape
# Out:
# (331262, 12)

# %%
positive_reviews_df.head()
# Out:
#    Id   ProductId          UserId                    ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                     delmartian
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T  Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                 Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1              David C. Sullivan
# 7   8  B006K2ZZ7K  A3JRGQVEQN31IQ             Pamela G. Williams
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 4                     0                       0      5  1350777600
# 5                     0                       0      4  1342051200
# 6                     0                       0      5  1340150400
# 7                     0                       0      5  1336003200
#
#                                          Summary  \
# 0                          good quality dog food
# 4                                    great taffy
# ...

# %% [markdown]
# PERFORMING EDA FOR NEGATIVE REVIEWS

# %%
#CREATING A NEW SERIES FOR ALL THE NEGATIVE REVIEW RECORDS
negative_reviews_df=reviews_df[reviews_df['Summary_Polarity']<0]

# %%
negative_reviews_df.head()
# Out:
#     Id   ProductId          UserId     ProfileName  HelpfulnessNumerator  \
# 16  17  B001GVISJM  A3KLWF6WQ5BNYO  Erica Neathery                     0
# 26  27  B001GVISJM  A3RXAU2N8KV45G          lady21                     0
# 57  58  B004N5KULM   ASCNNAJU6SXF8         S. Beck                     1
# 61  62  B004N5KULM   A7ZK2A3VIW7X9           Peggy                     0
# 62  63  B001EO5TPM  A1E09XGZUR78C6   gary sturrock                     2
#
#     HelpfulnessDenominator  Score        Time                Summary  \
# 16                       0      2  1348099200             poor taste
# 26                       1      1  1332633600        nasty no flavor
# 57                       1      5  1336176000  how can you go wrong!
# 61                       2      5  1319414400       pretty expensive
# 62                       2      1  1215302400         stale product.
#
#                                                  Text       Summary_Cleaned  \
# ...

# %%
negative_reviews_df.shape
# Out:
# (52311, 12)

# %% [markdown]
# WHICH USERS SHOULD AMAZON RECOMMEND MORE USERS?

# %%
reviews_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  good quality dog food  I have bought several of the Vitality canned d...
# ...

# %%
#GROUPING THE DATASET BY USERID
recommend_users=reviews_df.groupby('UserId').agg({'Summary':'count', 'Text':'count', 'ProductId':'count', 'Score':'mean'}).sort_values(by='ProductId', ascending=False)
recommend_users
# Out:
#                 Summary  Text  ProductId     Score
# UserId
# A3OXHLG6DIBRW8      448   448        448  4.535714
# A1YUL9PCJR3JTY      421   421        421  4.494062
# AY12DBB0U420B       389   389        389  4.647815
# A281NPSIMI1C2R      365   365        365  4.841096
# A1Z54EM24Y40LL      256   256        256  4.453125
# ...                 ...   ...        ...       ...
# A2HROR28DMJV2W        1     1          1  5.000000
# A2HRR8CO2Y20G8        1     1          1  5.000000
# A2HRSML93IK9TR        1     1          1  5.000000
# A2HRSUTNPGUU3G        1     1          1  4.000000
# AZZZOVIBXHGDR         1     1          1  2.000000
#
# [256047 rows x 4 columns]

# %%
# CHANGING THE COLUMN NAME
recommend_users.columns = ['no_of_summaries', 'no_of_text', 'total_products_purchased', 'avg_score']

# %%
recommend_users.head()
# Out:
#                 no_of_summaries  no_of_text  total_products_purchased  \
# UserId
# A3OXHLG6DIBRW8              448         448                       448
# A1YUL9PCJR3JTY              421         421                       421
# AY12DBB0U420B               389         389                       389
# A281NPSIMI1C2R              365         365                       365
# A1Z54EM24Y40LL              256         256                       256
#
#                 avg_score
# UserId
# A3OXHLG6DIBRW8   4.535714
# A1YUL9PCJR3JTY   4.494062
# AY12DBB0U420B    4.647815
# A281NPSIMI1C2R   4.841096
# A1Z54EM24Y40LL   4.453125

# %%
# TOP 10 USERS WHOM AMAZON SHOULD RECOMMEND MORE PRODUCT
top_10_users = recommend_users[0:10].reset_index()
top_10_users
# Out:
#            UserId  no_of_summaries  no_of_text  total_products_purchased  \
# 0  A3OXHLG6DIBRW8              448         448                       448
# 1  A1YUL9PCJR3JTY              421         421                       421
# 2   AY12DBB0U420B              389         389                       389
# 3  A281NPSIMI1C2R              365         365                       365
# 4  A1Z54EM24Y40LL              256         256                       256
# 5  A1TMAVN4CEM8U8              204         204                       204
# 6  A2MUGFV2TDQ47K              201         201                       201
# 7  A3TVZM3ZIXG8YW              199         199                       199
# 8  A3PJZ8TU8FDQ1K              178         178                       178
# 9   AQQLWCMRNDFGI              176         176                       176
#
#    avg_score
# 0   4.535714
# 1   4.494062
# 2   4.647815
# 3   4.841096
# 4   4.453125
# 5   4.833333
# 6   3.751244
# 7   1.000000
# 8   4.601124
# 9   3.954545

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=top_10_users['UserId'], y=top_10_users['total_products_purchased'])
plt.xlabel('User Ids', fontsize = 20)
plt.xticks(fontsize=13, rotation=45)
plt.ylabel('Total Product Purchased', fontsize = 20)
plt.yticks(fontsize=13)
plt.title('Total Product Purchase by User Id', fontsize = 24, fontweight = 'bold')

plt.show();

# %% [markdown]
# CLEANING THE TEXT COLUMN

# %%
#CONVERTING THE TEXT COLUMN INTO LOWERCASE
reviews_df['Text'] = reviews_df['Text'].str.lower()

# %%
reviews_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  good quality dog food  i have bought several of the vitality canned d...
# ...

# %%
# IMPORTING REGEX LIBRARY
import re

# %%
# Storing a sample record from the Text Column into the text
text=reviews_df['Text'][164]
text
# Out:
# 'seriously this product was as tasteless as they come. there are much better tasting products out there but at 100 calories its better than a special k bar or cookie snack pack. you just have to season it or combine it with something else to share the flavor.'

# %%
# Removing the puncutation in the record by passing it to the method
re.sub(r'[^\w\s]', '', text)
# Out:
# 'seriously this product was as tasteless as they come there are much better tasting products out there but at 100 calories its better than a special k bar or cookie snack pack you just have to season it or combine it with something else to share the flavor'

# %%
# Creating a for loop to remove the puncuation from all the records and then stroing it into a new series
Text_Cleaned = []
for char in reviews_df['Text']:
    Text_Cleaned.append(re.sub(r'[^\w\s]', '', char))

# %%
# Checking the length of the new series
len(Text_Cleaned)
# Out:
# 568411

# %%
# Checking the first 5 records of the new series
Text_Cleaned[0:5]
# Out:
# ['i have bought several of the vitality canned dog food products and have found them all to be of good quality the product looks more like a stew than a processed meat and it smells better my labrador is finicky and she appreciates this product better than  most',
#  'product arrived labeled as jumbo salted peanutsthe peanuts were actually small sized unsalted not sure if this was an error or if the vendor intended to represent the product as jumbo',
#  'this is a confection that has been around a few centuries  it is a light pillowy citrus gelatin with nuts  in this case filberts and it is cut into tiny squares and then liberally coated with powdered sugar  and it is a tiny mouthful of heaven  not too chewy and very flavorful  i highly recommend this yummy treat  if you are familiar with the story of cs lewis the lion the witch and the wardrobe  this is the treat that seduces edmund into selling out his brother and sisters to the witch',
# ...

# %%
# Removing Extra Spaces in the data
'''
+ matches one or more occurrences of the pattern left to it.
'''
Text_cleaned = []
for char in Text_Cleaned:
    Text_cleaned.append(re.sub(' +', ' ',char))

# %%
# Checking the first 5 records of the new series
Text_cleaned[0:5]
# Out:
# ['i have bought several of the vitality canned dog food products and have found them all to be of good quality the product looks more like a stew than a processed meat and it smells better my labrador is finicky and she appreciates this product better than most',
#  'product arrived labeled as jumbo salted peanutsthe peanuts were actually small sized unsalted not sure if this was an error or if the vendor intended to represent the product as jumbo',
#  'this is a confection that has been around a few centuries it is a light pillowy citrus gelatin with nuts in this case filberts and it is cut into tiny squares and then liberally coated with powdered sugar and it is a tiny mouthful of heaven not too chewy and very flavorful i highly recommend this yummy treat if you are familiar with the story of cs lewis the lion the witch and the wardrobe this is the treat that seduces edmund into selling out his brother and sisters to the witch',
# ...

# %%
# Storing the cleaned Series back to the original DataFrame
reviews_df['Text_Cleaned'] = Text_cleaned

# %%
reviews_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  good quality dog food  i have bought several of the vitality canned d...
# ...

# %% [markdown]
# CHECKING THE TEXT_CLEANED COLUMN FOR HYPERLINKS

# %%
# Checking the no.of records having URLs in them
reviews_df['Text_Cleaned'].str.contains('http|href').sum()
# Out:
# 11682

# %%
reviews_df[reviews_df['Text_Cleaned'].str.contains('http|href')]['Text_Cleaned']
# Out:
# 21        i bought these for my husband who is currently...
# 25        product received is as advertisedbr br a hrefh...
# 39        i ordered this for my wife as it was reccomend...
# 348       these are delicious the chocolate is excellent...
# 369       green mountain nantucket blend kcups make a ve...
#                                 ...
# 568185    i recently tried some very expensive highly re...
# 568285    a hrefhttpwwwamazoncomgpproductb001izhzjanestl...
# 568310    if you are looking for a tasty snack look no f...
# 568407    my 6 month old male tuxedo cat likes premium e...
# 568422    this version of pacific chai is pretty mild i ...
# Name: Text_Cleaned, Length: 11682, dtype: object

# %%
# Printing a sample record from the Dataset 
reviews_df['Text_Cleaned'][21]
# Out:
# 'i bought these for my husband who is currently overseas he loves these and apparently his staff likes them alsobr there are generous amounts of twizzlers in each 16ounce bag and this was well worth the price a hrefhttpwwwamazoncomgpproductb001gvisjmtwizzlers strawberry 16ounce bags pack of 6a'

# %%
# Importing Regex Library
import re

# %%
# Removing the URLs from the sample record
'''
\w :Returns a match where the string contains any word characters 
    (characters from a to Z, digits from 0-9, and the underscore _ character)
 + : matches one or more occurrences of the pattern left to it.
'''
url_pattern = re.compile(r'href|http.\w+')
url_pattern.sub(r'',reviews_df['Text_Cleaned'][21])
# Out:
# 'i bought these for my husband who is currently overseas he loves these and apparently his staff likes them alsobr there are generous amounts of twizzlers in each 16ounce bag and this was well worth the price a  strawberry 16ounce bags pack of 6a'

# %%
# Creating a function to loop over entire Text_Cleaned Column in the DataFrame
'''
\w :Returns a match where the string contains any word characters 
    (characters from a to Z, digits from 0-9, and the underscore _ character)
 + : matches one or more occurrences of the pattern left to it.
'''
def remove_urls(string):
    url_pattern = re.compile(r'href|http.\w+')
    return url_pattern.sub(r'',string)

# %%
# Calling the function and Storing the Cleaned Data back in Original Text_Cleaned Column of the DataFrame
reviews_df['Text_Cleaned'] = reviews_df['Text_Cleaned'].apply(remove_urls)

# %% [markdown]
# REMOVING STOP WORDS FROM THE TEXT COLUMN

# %%
# Importing Natural Language Toolkit 
from nltk.corpus import stopwords

# %%
# Storing a sample text record
sample = Text_Cleaned[0]
sample
# Out:
# 'i have bought several of the vitality canned dog food products and have found them all to be of good quality the product looks more like a stew than a processed meat and it smells better my labrador is finicky and she appreciates this product better than  most'

# %%
# Removing all the stop words from the sample text
non_stopwords = [word for word in sample.split(' ') if word not in set(stopwords.words('english'))]
non_stopwords
# Out:
# ['bought',
#  'several',
#  'vitality',
#  'canned',
#  'dog',
#  'food',
#  'products',
#  'found',
#  'good',
#  'quality',
#  'product',
#  'looks',
#  'like',
#  'stew',
#  'processed',
#  'meat',
#  'smells',
#  'better',
#  'labrador',
#  'finicky',
#  'appreciates',
#  'product',
#  'better',
#  '']

# %%
# Combining all the above non stop words back to form a single string using for loop
final_str = ''

for word in non_stopwords:
    final_str = final_str + word
    final_str = final_str + ' '
    
final_str
# Out:
# 'bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better  '

# %%
# Creating a sample DataFrame as the Original Dataframe is too large to run the above process

sample_df = reviews_df[0:5000]

# %%
sample_df
# Out:
#         Id   ProductId          UserId                      ProfileName  \
# 0        1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1        2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2        3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3        4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4        5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...    ...         ...             ...                              ...
# 4995  4996  B00653KJ5M   AGE64SY3HP9RV                               CZ
# 4996  4997  B00653KJ5M   A1MPEPNJ2NKWM             Rachel Albert Matesz
# 4997  4998  B00653KJ5M  A1T6I625FGQS20                               IL
# 4998  4999  B00653KJ5M  A3POAWC2JPQQQP                               me
# 4999  5000  B00653KJ5M  A122CSYJ3YSKI0                          Shaimun
#
#       HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
# Creating a function to remove the stop words in the Text_cleaned Columns
def remove_stopwords(string):
    return ' '.join([word for word in string.split(' ') if word not in set(stopwords.words('english'))])

# %%
# Calling the function and Storing back the cleaned data back into the new column of the DataFrame
sample_df['Text_Cleaned_non_stopwords'] = sample_df['Text_Cleaned'].apply(remove_stopwords)
# Out:
# C:\Users\prana\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
sample_df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  good quality dog food  i have bought several of the vitality canned d...
# ...
